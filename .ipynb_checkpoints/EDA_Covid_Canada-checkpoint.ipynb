# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import-Modules" data-toc-modified-id="Import-Modules-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import Modules</a></span></li><li><span><a href="#Functions" data-toc-modified-id="Functions-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Functions</a></span></li><li><span><a href="#Get-Data" data-toc-modified-id="Get-Data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Get Data</a></span></li></ul></div>

# %% [markdown]
# ## Import Modules

# %%
# Table libraries
import numpy as np 
import pandas as pd
from pandas import Series, DataFrame
from numpy.random import randn
import pickle


# Web scrapping libraries 
import lxml.html as lh
from bs4 import BeautifulSoup
import requests

# Other libraries
import os, sys
import re
import time
import csv


# Visualisation libraries
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
import pycountry
import plotly.express as px
from plotly.offline import init_notebook_mode, iplot 
import plotly.graph_objs as go
import plotly.offline as py
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

py.init_notebook_mode(connected=True)
import folium 
#from folium import plugins
#plt.style.use("fivethirtyeight")# for pretty graphs

# Increase the default plot size and set the color scheme
plt.rcParams['figure.figsize'] = 8, 5

# Disable warnings 
import warnings
warnings.filterwarnings('ignore')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Functions

# %%
# Highlight Max Numbers

def highlight_max(s):
    is_max = s == s.max()
    return ['background-color: pink' if v else '' for v in is_max]

# %% [markdown]
# ## Get Data

# %%
ca_data_df = pd.read_excel('Data/Covid_Canada.xlsx', 'Canada')
ca_data_df.head(3)
# Out:
#             Province  Tests  Conf.  Pres.  Confirmed  Population  \
# 0   British Columbia  38697    884      0        884     5110917
# 1            Alberta  42527    621      0        621     4413146
# 2       Saskatchewan   8248    134      0        134     1181666
#
#    Confirmed_PerMillion  Recovered  Deaths  Active  Land_Area_Sqkm  \
# 0                 173.0        396      17     471       922503.01
# 1                 140.7         53       2     566       640330.46
# 2                 113.4          4       0     130       552370.99
#
#    Popul_Density_Sqkm      Lat      Long
# 0            5.540271  49.2827 -123.1207
# 1            6.891982  53.9333 -116.5765
# 2            2.139262  52.9399 -106.4509

# %%
ca_data_df.style.apply(highlight_max,subset=['Confirmed', 'Confirmed_PerMillion', 'Deaths','Active','Popul_Density_Sqkm' ])
# Out:
# <style  type="text/css" >
#     #T_a4c21d30_71fc_11ea_8216_972778aeb822row5_col4 {
#             background-color:  pink;
#         }    #T_a4c21d30_71fc_11ea_8216_972778aeb822row5_col6 {
#             background-color:  pink;
#         }    #T_a4c21d30_71fc_11ea_8216_972778aeb822row5_col8 {
#             background-color:  pink;
#         }    #T_a4c21d30_71fc_11ea_8216_972778aeb822row5_col9 {
#             background-color:  pink;
#         }    #T_a4c21d30_71fc_11ea_8216_972778aeb822row8_col11 {
#             background-color:  pink;
#         }</style><table id="T_a4c21d30_71fc_11ea_8216_972778aeb822" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Province</th>        <th class="col_heading level0 col1" >Tests</th>        <th class="col_heading level0 col2" >Conf.</th>        <th class="col_heading level0 col3" >Pres.</th>        <th class="col_heading level0 col4" >Confirmed</th>        <th class="col_heading level0 col5" >Population</th>        <th class="col_heading level0 col6" >Confirmed_PerMillion</th>        <th class="col_heading level0 col7" >Recovered</th>        <th class="col_heading level0 col8" >Deaths</th>        <th class="col_heading level0 col9" >Active</th>        <th class="col_heading level0 col10" >Land_Area_Sqkm</th>        <th class="col_heading level0 col11" >Popul_Density_Sqkm</th>        <th class="col_heading level0 col12" >Lat</th>        <th class="col_heading level0 col13" >Long</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a4c21d30_71fc_11ea_8216_972778aeb822level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row0_col0" class="data row0 col0" > British Columbia</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row0_col1" class="data row0 col1" >38697</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row0_col2" class="data row0 col2" >884</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row0_col4" class="data row0 col4" >884</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row0_col5" class="data row0 col5" >5110917</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row0_col6" class="data row0 col6" >173</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row0_col7" class="data row0 col7" >396</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row0_col8" class="data row0 col8" >17</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row0_col9" class="data row0 col9" >471</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row0_col10" class="data row0 col10" >922503</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row0_col11" class="data row0 col11" >5.54027</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row0_col12" class="data row0 col12" >49.2827</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row0_col13" class="data row0 col13" >-123.121</td>
#             </tr>
#             <tr>
#                         <th id="T_a4c21d30_71fc_11ea_8216_972778aeb822level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row1_col0" class="data row1 col0" > Alberta</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row1_col1" class="data row1 col1" >42527</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row1_col2" class="data row1 col2" >621</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row1_col3" class="data row1 col3" >0</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row1_col4" class="data row1 col4" >621</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row1_col5" class="data row1 col5" >4413146</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row1_col6" class="data row1 col6" >140.7</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row1_col7" class="data row1 col7" >53</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row1_col8" class="data row1 col8" >2</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row1_col9" class="data row1 col9" >566</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row1_col10" class="data row1 col10" >640330</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row1_col11" class="data row1 col11" >6.89198</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row1_col12" class="data row1 col12" >53.9333</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row1_col13" class="data row1 col13" >-116.576</td>
#             </tr>
#             <tr>
#                         <th id="T_a4c21d30_71fc_11ea_8216_972778aeb822level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row2_col0" class="data row2 col0" > Saskatchewan</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row2_col1" class="data row2 col1" >8248</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row2_col2" class="data row2 col2" >134</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row2_col3" class="data row2 col3" >0</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row2_col4" class="data row2 col4" >134</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row2_col5" class="data row2 col5" >1181666</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row2_col6" class="data row2 col6" >113.4</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row2_col7" class="data row2 col7" >4</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row2_col8" class="data row2 col8" >0</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row2_col9" class="data row2 col9" >130</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row2_col10" class="data row2 col10" >552371</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row2_col11" class="data row2 col11" >2.13926</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row2_col12" class="data row2 col12" >52.9399</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row2_col13" class="data row2 col13" >-106.451</td>
#             </tr>
#             <tr>
#                         <th id="T_a4c21d30_71fc_11ea_8216_972778aeb822level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row3_col0" class="data row3 col0" > Manitoba</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row3_col1" class="data row3 col1" >6203</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row3_col2" class="data row3 col2" >61</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row3_col3" class="data row3 col3" >3</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row3_col4" class="data row3 col4" >64</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row3_col5" class="data row3 col5" >1377517</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row3_col6" class="data row3 col6" >46.5</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822row3_col7" class="data row3 col7" >0</td>
#                         <td id="T_a4c21d30_71fc_11ea_8216_972778aeb822r

# %%
f, ax = plt.subplots(figsize=(12, 8))
data = ca_data_df[['Province','Confirmed','Recovered','Deaths']]
data.sort_values('Confirmed',ascending=False,inplace=True)

sns.set_color_codes("pastel")
sns.barplot(x="Confirmed", y="Province", data=data,
            label="Total", color="r")

sns.set_color_codes("muted")
sns.barplot(x="Recovered", y="Province", data=data,
            label="Recovered", color="g")

sns.set_color_codes("muted")
sns.barplot(x="Deaths", y="Province", data=data,
            label="Deaths", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 3000), ylabel="",
       xlabel="Cases")
sns.despine(left=True, bottom=True)

# %%
# create map and display it
# color='#3186cc'

ca_lat, ca_long = 56.130367, -106.346771
zoom_start = 2.3

ca_map = folium.Map(location=[ca_lat, ca_long], zoom_start=zoom_start, tiles='OpenStreetMap', control_scale=True)

for lat, lon, value, name in zip(ca_data_df['Lat'], ca_data_df['Long'], ca_data_df['Confirmed'], ca_data_df['Province']):
    folium.CircleMarker([lat, lon],
                        radius=value/120,
                        popup = ('<strong>Province/Territory</strong>: ' + str(name).capitalize() + '<br>'
                                '<strong>Confirmed Cases</strong>: ' + str(value) + '<br>'),
                        color='crimson',fill=True,fill_color='crimson',line_opacity=0.5).add_to(ca_map)

ca_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# create map and display it

ca_lat, ca_long = 56.130367, -106.346771
zoom_start = 2.3

ca_map = folium.Map(location=[ca_lat, ca_long], zoom_start=zoom_start, tiles='OpenStreetMap', control_scale=True)

for lat, lon, value, name in zip(ca_data_df['Lat'], ca_data_df['Long'], ca_data_df['Confirmed'],ca_data_df['Province']):
    folium.Marker(location=[lat-0.8, lon-0.8],popup=('<strong>Confirmed</strong>: ' + str(value)),icon=folium.Icon(icon='cloud')).add_to(ca_map)
    folium.Marker(location=[lat+0.5, lon+0.5],popup=('<strong>Deaths</strong>: ' + str(value)),icon=folium.Icon(color='black')).add_to(ca_map)
    folium.Marker(location=[lat, lon],popup=('<strong>Active</strong>: ' + str(value)),icon=folium.Icon(color='red', icon='info-sign')).add_to(ca_map)
    
ca_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#folium_map = folium.Map(location=[38, -97],zoom_start=4.4,tiles='CartoDB dark_matter')

from folium.plugins import FastMarkerCluster, MarkerCluster

folium_map = folium.Map(location=[ca_lat, ca_long], zoom_start=zoom_start, tiles='OpenStreetMap', control_scale=True)

mc = MarkerCluster(name="Marker Cluster")

for index, row in ca_data_df.dropna().iterrows():
    popup_text = "{}<br> Active: {:,} <br> Confirmed: {:,}".format(
        index,row["Active"],row["Confirmed"]
                      )
    folium.CircleMarker(location=[row["Lat"],row["Long"]],
                        radius= 10,
                        color="red",
                        popup=popup_text,
                        fill=True).add_to(mc)

mc.add_to(folium_map)

folium.LayerControl().add_to(folium_map)
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for i in range(0,len(ca_data_df)):
    location=[ca_data_df.iloc[i]['Long'], ca_data_df.iloc[i]['Lat']]
    p=ca_data_df.iloc[i]['Province']
    radius=ca_data_df.iloc[i]['Confirmed']*10
    print(location, p, radius)
# Out:
# [-123.1207, 49.2827]  British Columbia 8840
# [-116.5765, 53.9333]  Alberta 6210
# [-106.4509, 52.9399]  Saskatchewan 1340
# [-98.8139, 53.7609]  Manitoba 640
# [-85.3232, 51.2538]  Ontario 11440
# [-73.5491, 52.9399]  Quebec 24980
# [-66.4619, 46.5653]  New Brunswick 510
# [-63.4168, 46.5107]  Prince Edward Island 110
# [-63.7443, 44.682]  Nova Scotia 1100
# [-66.4619, 46.5653]  Newfoundland and Labrador 1200
# [-135.0, 64.2823]  Yukon 40
# [-124.8457, 64.8255]  Northwest Territories 10
# [91.0, 73.0]  Nunavut 0
# [0.0, 0.0]  Repatriated travellers 130
